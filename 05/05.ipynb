# %% [markdown]
# # 05 데이터 분석 기초

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 05-1 데이터 파악하기
# - head() : 앞부분 출력
# - tail() : 뒷부분 출력
# - shape : 행열 개수
# - info() : 변수 속성 출력
# - describe() : 요약 통계량 측정

# %%
exam = pd.read_csv('../data/exam.csv')

# %%
# pandas.DataFramehead(n=5) : Return the first n rows
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.head(10)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %%
# pandas.DataFrame.tail(n=5) : Return the last n rows
exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# pandas.DataFrame.shape : Return a tuple representing the dimensionality of the DataFrame
exam.shape
# Out:
# (20, 5)

# %%
# pandas.DataFrame.info() : Print a concise summary of a DataFrame including the index dtype and columns, non-null values and memory usage
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
# pandas.DataFrame.describe() : Generate descriptive statistics
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# ### mpg 데이터 파악하기
# - Varialbes
#  - manufacturer : 제조 회사
#  - model : 자동차 모델명
#  - displ : 배기량(displacement)
#  - year : 생산 연도
#  - cyl : 실린더 개수(cylinders)
#  - trans : 변속기 종류(transmission)
#  - drv : 구동 방식(drive wheel)
#  - cty : 도시 연비(city)
#  - hwy : 고속도로 연비(highway)
#  - fl : 연료 종류(fuel)
#  - category : 자동차 종류

# %%
# Read mpg.csv to mpg
mpg = pd.read_csv('../data/mpg.csv')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %% [markdown]
# ## 05-2 변수명 바꾸기
# - pandas.DataFrame.rename() : Alter axes labels

# %%
df_temp = pd.DataFrame({'var1' : [1, 2, 3], 'var2' : [4, 5, 6]})
df_temp
# Out:
#    var1  var2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
# pandas.DataFrame.copy(deep=True) : Make a copy of this object’s indices and data
# When deep=True (default), a new object will be created with a copy of the calling object’s data and indices. 
# Modifications to the data or indices of the copy will not be reflected in the original object (see notes below).
# When deep=False, a new object will be created without copying the calling object’s data or index (only references to the data and index are copied). 
# Any changes to the data of the original will be reflected in the shallow copy (and vice versa).

df_new = df_temp.copy()
df_new
# Out:
#    var1  var2
# 0     1     4
# 1     2     5
# 2     3     6

# %%
# pandas.DataFrame.rename()
df_new = df_new.rename(columns = {'var2' : 'v2'})    # Alter var2 to v2
df_new
# Out:
#    var1  v2
# 0     1   4
# 1     2   5
# 2     3   6

# %% [markdown]
# ### 혼자서 해보기
# Q1. mpg 데이터를 불러와 복사본을 만드세요.
# Q2. 복사본 데이터를 이용해 cty는 city로, hwy는 highway로 수정하세요.
# Q3. 데이터 일부를 출력해 변수명이 바뀌었는지 확인해보세요.

# %%
# Q1
mpg = pd.read_csv('../data/mpg.csv')
new = mpg.copy()
new
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# Q2
new = new.rename(columns = {'cty' : 'city', 'hwy' : 'highway'})
new.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'city',
#        'highway', 'fl', 'category'],
#       dtype='object')

# %%
# Q3
new.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 4         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#   category
# 0  compact
# 1  compact
# 2  compact
# 3  compact
# 4  compact

# %% [markdown]
# ## 05-3 파생변수 만들기

# %% [markdown]
# 변수 두 개(var1, var2)로 구성된 데이터프레임을 만들고,
# 두 변수의 합인 var_sum과 두 변수의 평균인 var_mean이라는 파생변수를 만들어 추가하기

# %%
df = pd.DataFrame({'var1' : [4, 3, 8], 'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df['var_sum'] = df['var1'] + df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean'] = df['var_sum'] / 2
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기
# mpg 통합 연비 변수(total)이 기준을 충족해 고연비 합격 판정을 받은 자동차가 몊 대나 되는지 알아보기.

# %% [markdown]
# 1. total = (cty + hwy) / 2

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %% [markdown]
# 2. 기준값 정하기
# total의 연비와 중앙값이 약 20
# total이 20~22.5 사이인 자동차 모델이 가장 많고, 대부분 25 이하
# 따라서 기준값을 20으로 설정

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
# pandas.DataFrame.hist() : Make a histogram of the DataFrame’s columns
mpg['total'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# 3. 합격 판정 변수(test) 만들기

# %%
# numpy.where(condition, [x, y, ]/) : Return elements chosen from x or y depending on condition
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')    # If mpg['total'] >= 20, then mpg['test'] = 'pass', else mpg['test'] = 'fail'
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  pass
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  pass

# %% [markdown]
# 4. 빈도표로 합격 판정 자동차 수 알아보기

# %%
# pandas.DataFrame.value_counts() : Return a Series containing counts of unique rows in the DataFrame
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %% [markdown]
# 5. 막대그래프로 빈도 표현하기

# %%
test_cnt = mpg['test'].value_counts()    # 연비 합격 빈도표를 변수에 할당

# pandas.DataFrame.plot.bar() : Vertical bar plot
test_cnt.plot.bar()
# Out:
# <AxesSubplot:>

# %%
test_cnt.plot.bar(rot=0)    # 축 이름 수평으로 만들기
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 중첩조건문
# 연비 등급을 total 값이 30 이상이면 A, 20 이상 30 미만이면 B, 20 미만이면 C로 분류하여 연비 등급 변수(grade) 만들기

# %%
mpg['grade'] = np.where(mpg['total'] >= 30, 'A', 
                        np.where(mpg['total'] >= 20, 'B', 'C'))
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade
# 0   23.5  pass     B
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     B

# %%
grade_cnt = mpg['grade'].value_counts()
grade_cnt
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
grade_cnt.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
grade_cnt = grade_cnt.sort_index()    # Sort index in alphabetical order
grade_cnt
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
grade_cnt.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 목록에 해당하는 행으로 변수 만들기
# mpg의 size에 categroy가 compact, subcompact, 2seater면 small을, 아니면 large를 부여

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') 
                       | (mpg['category'] == 'subcompact') 
                       | (mpg['category'] == '2seater'), 'small', 'large')
# mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')
size_cnt = mpg['size'].value_counts()
size_cnt
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# # 분석 도전
# 문제 1. midwest.csv를 불러와 데이터의 특징을 파악하세요.
# 문제 2. poptotal(전체 인구) 변수를 total로, popasial(아시아 인구) 변수를 asian으로 수정하세요.
# 문제 3. total, asian 변수르 이용해 '전체 인구 대비 아시아 인구 백분율' 파생변수를 추가하고 히스토그램을 만들어 분포를 살펴보세요.
# 문제 4. 아시아 인구 백분율 전체 평균을 구하고, 평균을 초과하면 'large', 그 외에는 'small'을 부여한 파생변수를 만들어보세요.
# 문제 5. 'large'와 'small'에 해당하는 지역이 얼마나 많은지 빈도표와 빈도 막대 그래프를 만들어 확인하세요.

# %%
import pandas as pd
import numpy as np

# %%
# 문제 1. midwest.csv를 불러와 데이터의 특징을 파악하세요.

midwest = pd.read_csv('midwest.csv')
midwest
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percollege  percprof  poppovertyknown  \
# 0             98       249  ...   19.631392  4.355859            63628
# 1             19        48  ...   11.243308  2.870315            10529
# 2             35        16  ...   17.033819  4.488572            14235
# 3             46       150  ...   17.278954  4.197800            30337
# 4             14         5  ...   14.475999  3.367680             4815
#
#    percpovertyknown  percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# ...

# %%
midwest.tail()
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
#      popamerindian  popasian  ...  percollege  percprof  poppovertyknown  \
# 432            672      2699  ...   35.396784  7.667090           299802
# 433            125        92  ...   16.549869  3.138596            44412
# 434             70        43  ...   15.064584  2.620907            19163
# 435            685      1728  ...   24.995504  5.659847           133950
# 436            481       722  ...   21.666382  4.583725            72685
#
# ...

# %%
midwest.shape
# Out:
# (437, 28)

# %%
midwest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PID                   437 non-null    int64
#  1   county                437 non-null    object
#  2   state                 437 non-null    object
#  3   area                  437 non-null    float64
#  4   poptotal              437 non-null    int64
#  5   popdensity            437 non-null    float64
#  6   popwhite              437 non-null    int64
#  7   popblack              437 non-null    int64
#  8   popamerindian         437 non-null    int64
#  9   popasian              437 non-null    int64
#  10  popother              437 non-null    int64
#  11  percwhite             437 non-null    float64
#  12  percblack             437 non-null    float64
#  13  percamerindan         437 non-null    float64
#  14  percasian             437 non-null    float64
# ...

# %%
midwest.describe()
# Out:
#                PID        area      poptotal    popdensity      popwhite  \
# count   437.000000  437.000000  4.370000e+02    437.000000  4.370000e+02
# mean   1437.338673    0.033169  9.613030e+04   3097.742985  8.183992e+04
# std     876.390266    0.014679  2.981705e+05   7664.751786  2.001966e+05
# min     561.000000    0.005000  1.701000e+03     85.050000  4.160000e+02
# 25%     670.000000    0.024000  1.884000e+04    622.407407  1.863000e+04
# 50%    1221.000000    0.030000  3.532400e+04   1156.208330  3.447100e+04
# 75%    2059.000000    0.038000  7.565100e+04   2330.000000  7.296800e+04
# max    3052.000000    0.110000  5.105067e+06  88018.396600  3.204947e+06
#
#            popblack  popamerindian       popasian       popother   percwhite  \
# count  4.370000e+02     437.000000     437.000000     437.000000  437.000000
# mean   1.102388e+04     343.109840    1310.464531    1612.931350   95.558441
# std    7.895827e+04     868.926751    9518.394189   18526.540699    7.087358
# ...

# %%
# 문제 2. poptotal(전체 인구) 변수를 total로, popasian(아시아 인구) 변수를 asian으로 수정하세요.
midwest2 = midwest.copy()
midwest2 = midwest2.rename(columns={'poptotal' : 'total', 'popasian' : 'asian'})
midwest2.columns
# Out:
# Index(['PID', 'county', 'state', 'area', 'total', 'popdensity', 'popwhite',
#        'popblack', 'popamerindian', 'asian', 'popother', 'percwhite',
#        'percblack', 'percamerindan', 'percasian', 'percother', 'popadults',
#        'perchsd', 'percollege', 'percprof', 'poppovertyknown',
#        'percpovertyknown', 'percbelowpoverty', 'percchildbelowpovert',
#        'percadultpoverty', 'percelderlypoverty', 'inmetro', 'category'],
#       dtype='object')

# %%
# 문제 3. total, asian 변수르 이용해 '전체 인구 대비 아시아 인구 백분율' 파생변수를 추가하고 히스토그램을 만들어 분포를 살펴보세요.
midwest2['ratio'] = midwest2['asian'] / midwest2['total'] * 100
midwest2['ratio'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 문제 4. 아시아 인구 백분율 전체 평균을 구하고, 평균을 초과하면 'large', 그 외에는 'small'을 부여한 파생변수를 만들어보세요.
ratio_mean = midwest2['ratio'].mean()
midwest2['group'] = np.where(midwest2['ratio'] > ratio_mean, 'large', 'small')
midwest2.head()
# Out:
#    PID     county state   area  total   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052  66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014  10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022  14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017  30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018   5836   324.222222      5264       547
#
#    popamerindian  asian  ...  percpovertyknown  percbelowpoverty  \
# 0             98    249  ...         96.274777         13.151443
# 1             19     48  ...         99.087145         32.244278
# 2             35     16  ...         94.956974         12.068844
# 3             46    150  ...         98.477569          7.209019
# 4             14      5  ...         82.505140         13.520249
#
#    percchildbelowpovert  percadultpoverty  percelderlypoverty  inmetro  \
# 0             18.011717         11.009776           12.443812        0
# ...

# %%
# 문제 5. 'large'와 'small'에 해당하는 지역이 얼마나 많은지 빈도표와 빈도 막대 그래프를 만들어 확인하세요.
group_cnt = midwest2['group'].value_counts()
group_cnt
# Out:
# small    318
# large    119
# Name: group, dtype: int64

# %%
group_cnt.plot.bar(rot=0)
# Out:
# <AxesSubplot:>
